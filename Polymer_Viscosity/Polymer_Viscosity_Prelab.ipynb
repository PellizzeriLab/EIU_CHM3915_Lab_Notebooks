# %% [markdown]
# # Experiment 2 — Kinetics of the Fading of Phenolphthalein in Alkaline Solution
#
# **Pre-lab assignment**
#
# The following notes will help you prepare for the lab and think about the experimental setup and data analysis. Please use **Python** for all data manipulation and analysis.
#
# ---
#
# ### Background
# Macromolecules are exceptionally large molecules with molecular masses ranging from 1,000 – 1,000,000 g/mol. Polymers are a particular type of macromolecule that are made of repeating subunits called monomers.
#
# Polyvinyl alcohol will be the focus of this experiment.
#
# Polyvinyl alchohol is created through the polymerization of vinyl alchohol. An example is given below using 10 repeating units.
#
# ![PVA polymerization](PVA_Polymerization.png)

# %% [markdown]
# 1.	What is the empirical formula for PVA? What is the approximate density of PVA?

# %% [markdown]
# 2.	Calculate the approximate number of carbon atoms in a molecule of PVA with a molecular weight of 95,000 amu.

# %% [markdown]
# 3.	Calculate a very rough estimate for the length of the molecule in Question 3 if it could be stretched out into a straight line. Clearly state any assumptions.

# %% [markdown]
# 4.	If the molecule in Question 3 were coiled up into a solid sphere with the density you found in Question 2, what would be the diameter of the sphere? [Hint: recall the equation for the volume of a sphere.] How does this compare with the size of the stretched-out molecule?

# %% [markdown]
# 5.	Of the density, particle radius, and carbon-chain length, only one will increase linearly with the molecular weight of PVA. Which one and why?

# %% [markdown]
# 6.	PVA dissolves in water. Write a hypothesis about how dissolving PVA in water will affect the rate at which the liquid will flow through a narrow tube. Which will flow faster through a narrow tube, pure water or PVA solution, and why? This is **Hypothesis 1a**. In addition to providing your answer below, please also copy this into your lab notebook.

# %% [markdown]
# 7.	Which will flow faster through a narrow tube, PVA with a small molecular weight, or PVA with a large molecular weight? Why? This is **Hypothesis 1b**. In addition to providing your answer below, please also copy this into your lab notebook.

# %% [markdown]
# 8.	Assuming a PVA molecule in solution is approximately spherical, how would the volume of a single molecule be related to its mass? Develop a hypothesis relating to the size (i.e., radius) of a polymer sphere in solution to the polymer’s molecular weight. Write the equation below and include this in your notebook. Include your reasoning. **This is Hypothesis 2**.

# %% [markdown]
# Simulation of a uniform density polymer can be done by representing each monomer by one vertex on a graph. Mark a starting point about ten squares down and in the center of a sheet of paper.
#
# ![Prelab Question 9](Prelab_Q9.png)
#
# Draw a uniform density polymer by spiraling outward for eight more vertices (nine total). What is the area of your model polymer in (number of vertices) x (number of vertices)? Determine the exponent in
#
# $Object Size = Chain Length^{exponent}$
#
# This value can then be compared to the value obtained for α in the Mark-Houwink equation. This will be included in your lab report.

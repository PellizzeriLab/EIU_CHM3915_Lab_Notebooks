# %% [markdown]
# # Introduction to Python Programming
# This Jupyter notebook will contain exercies for you to complete and hand in to the dropbox on D2L.
#
# You may want to have a seperate notebook open for code testing before placing it in the provided box.
#
# The goal is for when I execute the code in the cell it should produce the correct response.
# ___

# %% [markdown]
# ### Exercise 1:
# >
# A 1.6285 L ($V$) flask contains 1.220 moles ($n$) of ideal gas at 273.0 K ($T$).
# Calculate the pressure ($P$) for the above system by assigning all values to variables and performing the mathematical operations on the variables. Remember that
#
# $$
# PV=nRT
# $$
#
# describes the relationship between $V, n, P,$ and $T$, where $R$=0.08206 L·atm/mol·K

# %% [markdown]
# ### Exercise 2:
#
# Assign x = 12 and then increase the value by 32 without typing “x = 32”.

# %% [markdown]
# ### Exercise 3:
#
# Solve the quadratic equation using the quadratic formula below for a = 1, b = 2, and c = 1.
#
# $$x=\frac{-b\pm \sqrt{b^2-4ac}}{2a}$$

# %% [markdown]
# ### Exercise 4:
# A single bond is comprised of a sigma bond while a double bond includes a sigma plus a pi bond. The following strings contain the bond energies (kJ/mol) for a typical C-C single bond and C=C double bond. Perform a mathematical operation on CC_single and CC_double to estimate how much energy a pi bond contributes to a C=C double bond.
#
# ``` python
# CC_single = "345"
# CC_double = "611"
# ```

# %% [markdown]
# ### Exercise 5:
# The following are the atomic numbers of lithium, carbon, and sodium. Assign each to a variable and use Python Boolean logic operators to evaluate each of the following.
#
# ```python
# Li, C, Na = 3, 6, 11
# ```
#
# a) Is Li greater than C?
#
# b) Is Na less than or equal to C?
#
# c) Is either Li or Na greater than C?
#
# d) Are both C and Na greater than Li?

# %% [markdown]
# ### Exercise 6:
# Generate a list containing the natural logs of integers from 2 $\rightarrow$ 23 (including 23) using append and then again using using list comprehension.

# %% [markdown]
# ### Exercise 7:
# Write a Python script that takes in the number of electrons and protons and determines if a compound is cationic, anionic, or neutral.

# %% [markdown]
# ### Exercise 8:
# Use the ```random``` module for the following.
#
# a) Generate 10 random integers from 0 $\rightarrow$ 9 and calculate the mean of these values. What is the theoretical mean for this data set?
#
# b) Generate 10,000 random integers from 0 $\rightarrow$ 9 and calculate the mean of these values. Is this mean closer or further than the mean from part a? Rationalize your answer. Hint: look up the “law of large numbers” for help.

# %% [markdown]
# ### Exercise 9:
# Using a "for" loop convert the following single point energy values in Hartree to both kJ/mol and kcal/mol
#
# ``` python
# spes = [-443.19225788, -443.225590922, -443.199437861,
#         -443.239444863, -443.217935422, -443.220253946,
#         -443.236066571, -443.22927076, -443.186725894, -443.232267518]
# ```

# %% [markdown]
# ### Exercise 10:
#
# Suppose we have analytically determined the diffusion coefficient at 24 °C to find the Stokes–Einstein radius of drug molecules in water (16). Assume the molecules are spheres. Calculate the Stokes–Einstein radius for all compounds in a for-loop.
#
# Stokes–Einstein equation for spherical system
#
# $$
# R_H = \frac{k_B T}{6 \pi \eta D}
# $$
#
# where $k_B$ is the Boltzmann’s constant ($1.38 × 10^{–23} J/K$), $T$ is the temperature, $\eta$ is the viscosity of the liquid, and $D$ is the diffusion coefficient of ion.
#
# ``` python
# drug_diffusion_coef = { # D in x10^(-6) cm^2/s
#     'caffeine': 9.0,
#     'calcein': 3.8,
#     'chloramphenicol': 6.6,
#     'ketoprofen': 6.4,
#     'nitrofurantoin': 7.1,
#     'paracetamol': 7.8,
#     'penicillin G': 6.5,
#     'tetracycline': 5.8,
#     'trimethoprim': 5.6,
#     'vancomycin': 2.9
# }
# ```
#     # write the rest of the code

# %% [markdown]
# ### Exercise 11:
# The isotope $^{137} Cs$
#  has a half-life about 30.2 years. Using a while loop, determine how many half-lives until a 500.0 g sample would have to decay until there is less that 10.00 grams left. To accomplish this, create a counter (counter = 0) and add 1 to it each cycle of a while loop to keep count.

# %% [markdown]
# ### Exercise 12:
# For the following problems, first run the following code to generate a test file containing simulated kinetics data.
#
# ``` python
# import math
# with open('data/test.csv', 'a') as file:
#     file.write('time, [A] \n')
#     for t in range(20):
#         file.write('%s, %s \n' % (t, math.exp(-0.5*t)))
# ```
#
# Using Python’s native ```open()``` and ```readlines()``` functions, open the test.txt file and print each line.

# %% [markdown]
# Using ```np.genfromtxt()```, read the test.txt file and append the time values to one list and the concentration values to a second list. You will need to skip a line in the file.

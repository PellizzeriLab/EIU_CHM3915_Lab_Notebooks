# %% [markdown]
# # Experiment 3 — Composition Phase Diagram and Activity Coefficients of a Binary System
#
# **Pre-lab assignment**
#
# The following notes will help you prepare for the lab and think about the experimental setup and data analysis. Please use **Python** for all data manipulation and analysis.
#
# This assignment contains information and practice calculations essential to your understanding of this experiment and the associated calculations. Please seek help if there is something you do not understand. You can find more help on this topic in your textbook. (Atkins, pages 176-185 and Shoemaker, pages 199-215).
#
# ---

# %% [markdown]
# ### Section 1: Questions to help with understanding. ###
#
# 1.	When the solution in the apparatus has come to equilibrium, it should be refluxing steadily with liquid splashing continually on the thermometer. Explain what will happen to the observed temperature on the thermometer if you now increase the overall pressure in the vessel by opening the metal vent valve briefly. Give your reasoning. Assume that the system has returned to equilibrium before you make your temperature measurement.

# %% [markdown]
# 2.	Assume that the sample tubes containing your liquid and condensed vapor phase samples were left on the bench uncapped and several hours later you took refractive index measurements and determined the composition. What errors, if any, will this introduce into your determination of the composition?

# %% [markdown]
# 3. A refractive index measurement of an unknown solution containing cyclohexane and ethanol is shown below. Give (a) the refractive index measurement and (b) use this measurement to deduce the approximate composition of the unknown solution. Give your composition in terms of a mole fraction of cyclohexane $(χ_{Cy} )$. You will need to use the RI-Fitting python notebook.Note: The Example refractive index shown below is read as 1.4164 and corresponds to a mole fraction of cyclohexane of 0.904606.
#
# ![Prelab Question 3](Prelab_Q3_new.png)

# %% [markdown]
# 4.	Predict what sort of deviation (positive, negative or none) you would expect from Raoult’s law for a mixture of ethanol and cyclohexane. Explain what this means in terms of the observed vapor pressure measurements of this solution.

# %% [markdown]
# 5.	Prove that the approximate mole fraction of cyclohexane in run #7 is about 0.1 (as shown in the procedure table on page 13 of the Procedure handout).
#
# Required information: density of cyclohexane = 0.7739 $\frac{g}{mL}$; density of ethanol = 0.78945 $\frac{g}{mL}$; molecular weights (cyclohexane) = 84.162 $\frac{g}{mol}$ and (ethanol) = 46.069 $\frac{g}{mol}$.

# %% [markdown]
# 6.	What would you expect to see for the measured refractive indices of the liquid and vapor phase samples if you were to take a sample from the mixture at exactly the azeotropic composition?

# %% [markdown]
# ----
#
# ### Section 2: Determining Experimental Data from Scatchard, G; Satkiewicz, F. G. J. Am. Chem. Soc. 1964, 86, 2, 130-133. ###
#
# 1. Draw up a table (using pandas) that shows your predicted total pressure readings for each of the ten runs shown in the Procedure Table. You can use the approximate mole fraction of cyclohexane, along with the literature data given in Reference 1 of your Procedure handout (available on D2L), to estimate a total pressure above the solution at each of your approximate compositions. Use this in the experiment to set the pressure to roughly where you expect to see the solution boil, wait for it to stabilize, and then adjust the pressure accordingly. Bear in mind that you will need to ADD the pressures $p_A$ and $p_B$ in the literature data table to obtain the TOTAL pressure above the solution.

# %% [markdown]
# 2.	Create an array or list with the literature total and partial pressures for cyclohexane and ethanol at 50°C. Plot this data using your python plotting template. This will be used in “Plot #1”.

# %% [markdown]
# 3. Create an array or list with the literature $\chi_{Cy}$  & $y_{cy}$ as a function of pressure at 50°C. Plot this data using your python plotting template. This will be used in “Plot #2”.

# %% [markdown]
# 4. Create an array or list with the literature Activity Coefficients $(\gamma_i)$ for cyclohexane and ethanol at 50°C. Plot this data using your python plotting template. This will be used in “Plot #3”.

# %% [markdown]
# 5. Create an array or list with the literature excess Gibbs energy $(G^E)$ in $\frac{J}{mol}$ at 50°C. Plot this data using your python plotting template. This will be used in “Plot #4”.
